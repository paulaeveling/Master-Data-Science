# %% [markdown]
# <h2>Cenário atual do Machine Learning</h2>
#
#
# - principais tarefas do machine learning
#     - regressao: algoritmos de previsao
#     - arvore de decisao: inducao de regras para fazer =classificacao
#     - cluster analysis: aprendizado nao supervisionado para identificar padroes nao percebidos
#
# - 3cs: classification, clustering, collaborative filtering

# %% [markdown]
# <h2>Processo de Machine Learning</h2>
#
# - atraves da experiencia melhorar processo automaticamente
# - interatividade é decorrente no processo de machine learning
# - algoritmos devem ser uteis e compreensiveis
# - normalmente processo realizado offline
# - etapas KDD (Zantinge)
#
# ![Screen%20Shot%202020-09-02%20at%209.10.23%20PM.png](attachment:Screen%20Shot%202020-09-02%20at%209.10.23%20PM.png)
#
# - CRISP DM (Cross industry standard process for data mining)
# - semelhante ao KDD
#
# ![Screen%20Shot%202020-09-02%20at%209.11.04%20PM.png](attachment:Screen%20Shot%202020-09-02%20at%209.11.04%20PM.png)
#
# - processo de ciencia de dados
# - grande mudanca esta na coleta de dados
# - machine learning - modelar dados
#
# ![Screen%20Shot%202020-09-02%20at%209.11.27%20PM.png](attachment:Screen%20Shot%202020-09-02%20at%209.11.27%20PM.png)

# %% [markdown]
# <h2>Estilos de aprendizado</h2>
#
# - supervisionado
#     - classes pre-definidas por especialistas
#     - construir modelo para classificar registros futuros
#     - tipicamente modelo de previsao de classificacao
#     - desempenho aceitavel
#     - inducao de regras
#     - regressao
#     - redes neurais multicamadas
#     - aprendizado baseado em instancias
#     - metodos baseados em kernels
#
#
# - nao supervisionado
#     - dado nao e rotulado ou resultado nao e conhecido
#     - nao existe classes conhecidas
#     - agrupamento de instancias (cluster)
#     - identificar anomalias
#     - redes neurais adversarias
#
#
# - semisupervisionado
#     - dados rotulados e nao rotulados
#     - normalmente utilizado quando e muito caro rotular dados
#     - metodos geradores
#     - separacao de baixa densidade (detectar dados agrupados ou nao)
#     - baseados em grafos
#     - metodos heuristicos
#
#
# - aprendizado por reforco
#     - ambiente computacional interage um ambiente dinamico
#     - metodo de monte carlo
#     - metodo de diferencas temporais

# %% [markdown]
# <h2>Tarefas da mineração de dados</h2>
#
# - descricao de dados:
#     - caracterizacao e comparacao
#     - descobrimento de regras
#     - correlacao para causalidade (sistemas de recomendacao)
#
#
# - classificacao e previsao
#     - classificacao baseada em valores
#     - estimacao de valores ou classes a partir de atributos
#     - clusterizacao ou segmentacao
#     - agrupar dados por semelhanca
#
#
# - analise de tendencias e desvios em series temporais
#     - encontrar e caracterizar tendencias
#     - definir padroes ao longo do tempo
#     - econtrar desvios de dados

# %% [markdown]
# <h2>Definição do problema</h2>
#
# - transformar pergunta de negocios para pergunta orientada a dados
# - alinhamento de variaveis

# %% [markdown]
# <h2>Redefinição do problema</h2>
#
# - tecnica de fatos e julgamentos
# - permite identificar questoes que nao estao diretamente com o problema mas podem ser uteis
# - fato: o que causou o problema
# - julgamentos: observacoes a serem disputadas ou decididos;

# %% [markdown]
# <h2>Preparação de dados: dados omissos</h2>
#
# - limpeza
# - enriquecimento
# - codificacao
# - feature engineering
#
# - principal problema sao dados omissos que devem ser analisados caso a caso
# - se dado nao for estrategico, pode ser removido
# - pode-se inferir valores

# %% [markdown]
# <h2>Preparação de dados: dados ruidosos</h2>
#
# - dados inconsistentes
# - dados inexatos
# - dados incompletos
#
#
# - aplicar tecnicas estatisticas para identificar problemas
# - ruidos de medicao: sensor, por exemplo
# - ruido de atributo: ruido de medicao ou aleatorio
# - ruido de classe: dado classificado errado
#
#
# - identificar como precisao dos dados esta sendo afetada
#
# - codificacao: preocupacao com padronizacao para analisar consistencia - dados devem utilizar mesma escala, mesmo formato

# %% [markdown]
# <h2>Preparação de dados: limpeza e seleção</h2>
#
# - campos podem ser irrelevantes, duplicados ou redundantes
# - podem produzir conhecimento falso
# - podem aumentar tempo de execucao dos algoritmos (complexidade exponencial)
# - engenharia de atributos: CEP (construir relacoes geograficas), CPF (nao esta relacionada com perfil), data de nascimento e idade (duplicadas)
# - dados conflitantes

# %% [markdown]
# <h2>Tipos de dados</h2>
#
# - quantitativo: discretos ou continuos
# - qualitativo: nominais ou ordinais
#
#
# - binominal / binario: qualitativo true ou false
#     - simetricos: ambos valores possue a mesma relevancia
#     - assimetricos: apenas valor positivo e relevante
#
#
# - categoricos polinomiais:
#     - nao ordinais: nao podem ser ordenados
#     - ordinais: podem ser ordenados (fria, morna, quente)
#
#
# - quantitativos:
#     - normalizados: faixa de valores limitada (0 e 1)
#     - nao normalizados: minimo e maximo; nao pode calcular razao; zero absoluto?

# %% [markdown]
# <h2>Regras de Associação: definições</h2>
#
# - objetivo: identificar padroes frequentas na base de dados
# - aplicacoes:
#     - analise de cestas de compras, marketing, catalogis
#         - quais subsequentes compras apos ter comprado um PC
#         - qual tipo de dna que e sensivel a uma nova droga
#         - como classicar documentos web
#
#
# - item: conjunto de valored que vao produzir dicionario
# - tamanho itemset: numero de elementos em um itemset
# - maioria dos algoritmos exigem que itens sejam organizados no itemset
# - divida em 2 etapas: identificar padroes frequentes e construir regras

# %% [markdown]
# <h2>Regras de Associação: suporte e confiança</h2>
#
# - exemplo: quem frequenta academia tambem gosta de tomar suplemento. Quais sao lugares estrategicos para colocar um stand para vender meu produto?
# - que tipos de lugares estao associados com que tipo de clientes?
# - como criar regras? essa regra deve ter suporte de % de acordo com base de dados
# - nao existe regra, tem que ter consenso
# - confianca mede o grau de certeza que A implica em B
# - conf (A -> B) = numero de transacoes que suportam (A U B) / numero de transacoes que suportam A

# %% [markdown]
# <h2>Regras de associação: conjuntos de itens frequentes</h2>
#
# - suporte e confianca minima: discartar regras que nao atingiram suporte/confianca minima

# %% [markdown]
# <h2>Regras de Associação: algoritmos</h2>
#
# - Algoritmo Apriori: usa conhecimento ja obtido dos itemsets anteriores
# - fase I: descobrir todos os conjuntos de itens com suporte maior ou igual a X (definido pelo usuario)
# - um subset de um itemset frequente tambem e um itemset frequente. Por exemplo: {AB} eh um itemset frequente, ambos {A} e {B} devem ser itemsets frequentes
# - fase II: descobrir regras de associacao com fator de confianca definido pelo usuario
#
#
# ![Screen%20Shot%202020-09-06%20at%2010.58.40%20AM.png](attachment:Screen%20Shot%202020-09-06%20at%2010.58.40%20AM.png)

# %% [markdown]
# - Algoritmo FP-growth (frequent pattern)
# - geracao de padroes frequentes de itens sem geracao de candidatos
# - mais eficiente e mais escalavel que o Apriori
# - fase I: constroi estrutura compacta chamada FP-tree
# - fase II: extrai itemsets frequentes da FP-tree
# - quando maior o suporte, menor a lista de candidatos
# - se comporta de forma mais linear

# %% [markdown]
# <h2>Regras de Associação: avaliação das regras</h2>
#
# - problema: suporte confianca alto e regra nao e util
# - padaria, por exemplo - todos compram pao
# - regra inutil: leite U pao (sup 30%, conf 75%)
# - criar medidas de interesse para avaliar qualidade da regra
# - Lift: indica forca de uma regra sobre a coocorrencia aleatoria de seus antecedentes e consequentes
# - lift deve ser superior a 1 para ser relevante
# - conviccao: sensivel a regra; muito relevante e grau de incerteza baixo
# - ganho: e calculado baseado em um valor theta dado;
#
#
# - Laplace: baseado em parametro k
# - Piatesky-Shaprio

# %% [markdown]
# <h2>Classificação e previsão - Definições</h2>
#
# - classificar e prever: descrever classes de dados e previsao
# - depende do resultado final esperado
# - se saida for continua, entao algoritmo de previsao
# - classificacao: febre, falta de apetite
# - previsao: num de quartos, regiao, elevadores etc
# - atributos podem ser combinados
#
#
# - etapa 1: criacao do modelo - aprendizado
# - criado a partir da base de treinamento
# - classificam registros base em conjunto de classes pre-definidas
#
#
# - etapa 2: verificacao do modelo - classificacao
# - regras sao testadas sobre outra base (base de teste)
# - aferir qualidade do modelo e medida em termos da % corretamente classificada
# - existem outras medidas que podem ser utilizadas para testar acuracia do modelo
# - dados sao rotulados
#
#
# - etapa 3: utilizacao do modelo - deploy
# - modelo implantado sobre novos dados (API de ML)
# - disponibilizacao do modelo depende da aplicacao
# - dados nao sao previamente rotulados, a aplicacao e responsavel por isso

# %% [markdown]
# <h2>Seleção de registros e atributos</h2>
#
# - Separar base de treinamento e de teste
# - devem ser semelhantes (estatistica, espaco etc)
# - pode-se partir a base, se base for grande (percentage split)
# - senao usar validacao cruzada (cross validation)
#
#
# - Percentage split
# - se base de dados for grande
# - particiona base por amostragem
# - tipos de amostragem interferem no resultado
#
#
# - cross validation
# - particiona em k partes
# - exemplo: 10 partes, 9 blocos para treinamento e 1 para teste
#
#
# - feature selection / feature engenieering
# - escolha dos atributos que serao utilizados para construcao do modelo
# - situacoes difices de tratar, como:
# - agregar quando for relevante
# - redundancia pode nao ser problema, mas afeta alguns algoritmos
# - pode-se usar reducao de dimensionalidade (pra melhorar desempenho)
# - dimensionalidade: pode-se perder interpretabilidade
# - afeta desempenho
#
#
# - criterios de escolha do algoritmo
# - classificacao ou previsao?
# - tipos de dados
# - distribuicao de classes sao balanceadas? (outliers)
# - interpretabilidade dos resultados: nem todos os modelos sao interpretaveis exemplo rede neural

# %% [markdown]
# <h2>Busca por Hiperparâmetros</h2>
#
#
# - busca por hiperparametros
# - distancia, por exemplo. Qual a distancia? Ha varias disponiveis no mercado
# - parametros: variaveis ajustadas no processo de aprendizado
# - hiperparametros: precisam ser ajustados, mas nao sao aprendidos
#
#
# - tecnicas por hiperparametros ou outotuning ou grid search sao tecnicas para ajustar hiperparametros
#
# - exemplo: classificador linear
# - precisa da variavel de folga: aceitar erro como irrelevante
#
#
# ![Screen%20Shot%202020-09-07%20at%2010.03.57%20PM.png](attachment:Screen%20Shot%202020-09-07%20at%2010.03.57%20PM.png)

# %% [markdown]
# <h2>Avaliação do modelo - Matriz de confusão</h2>
#
# - avaliar qualidade do modelo e ter certeza que ele esta adequado
#
#
# - matriz de confusao
# - modelo binario
# - mostra numero de classificacoes corretas vs classificacoes preditas para cada classe
# - classificador ideal possui valores nao nulos apenas na diagonal pq deve classificar sempre corretamente
# - problema: analisar impacto de falsos positivos e falsos negativos
# - revocacao: analisa capacidade de recuperar positivos
# - quanto maior certeza (precisao), menor a revocacao
# - quanto maior a revocacao, menor a precisao
#
# ![Screen%20Shot%202020-09-07%20at%2010.10.15%20PM.png](attachment:Screen%20Shot%202020-09-07%20at%2010.10.15%20PM.png)
#
#
# - acuracia por classe
# - media das acuracias individuais para cada classe
# - minimiza o problema de desbalanceamento de classe
# - desvantagem: se classe possui poucas amostras, aumenta a variancia da medida
# - minimiza problema, mas nao o resolve

# %% [markdown]
# <h2>Avaliação do modelo - Medidas de qualidade</h2>
#
# - log-loss
# - usado quando um classificado retorna uma probabilidade de classificacao
# - classificar baseado em confianca retornando probabilidade
# - expressoes nunca sao analisas simultaneamente
# - erro = 1; acerto = 2;
# - quanto maior a certeza, maior sera o log
# - log 50%, por exemplo: -1; 100% indeciso
# - analisa perda logaritmica
#
#
# - precisao
# - define os positivos verdadeiros
# - dentre os exemplos classificados como verdadeiros, quantos realmente eram verdadeiros
#
#
# - revocacao / sensitividade (recall)
# - capacidade de recuperacao da classe
# - entre classificados como verdadeiros, quantos foram verdadeiros
# - quando quero sensitividade alta: identificar risco cardiaco (melhor previnir dizendo que tem)
#
#
# - Especificidade
# - capacidade (%) de recuperar amostras negativas
#
#
# - F-measureou F-score
# - media ponderada da precisao e revocacao (que andam juntas)
# - reconhecimento de imagem, por exemplo
# - analisar qualidade do modelo

# %% [markdown]
# <h2>Árvore de decisão: Princípios</h2>
#
# - cada no e um atributo da base de dados
# - nos folha sao atributos-classe
# - cada ramo ligando um no-filho a um no pai e etiquetado com o valor do atributo no-pai
# - exemplo: idade (no-pai); adulto, crianca, idoso (nos-filho)
# - atributo no nao pode aparecer em seus nos descendentes; por exemplo, nao faz sentido ter adulto 2x
# - arvores dependem do tipo de dados
#
#
# - Inducao de arvore de decisao
# - ID3 (Iterative Dichotomiser): so aceita dados categoricos, nao funciona bem com dados omissos e outliers;
#
# - C45 (sucessor ID3): particionamento de dados continuos, arvore binaria, apenas 2 nos-filho
#
# - J48: similar ao C45
#
# - CART (Classification and Regression Trees): trabalha com dados continuos, ruidos, dados omissos
#
#
# ![Screen%20Shot%202020-09-08%20at%208.56.17%20AM.png](attachment:Screen%20Shot%202020-09-08%20at%208.56.17%20AM.png)

# %% [markdown]
# - parametros de entrada
# - base de dados (B)
# - lista de atributos candidatos (CAND)
# - um atributo-classe (rotulo): sempre categorico
#
#
# - metodos de selecao de atributos
# - ganho de informacao (ID3): sensivel a outliers
# - taxa de ganho (C45, J48): entropia; razao
# - Indice GINI - impureza (CART)

# %% [markdown]
# <h2>Árvore de decisão: ID3</h2>
#
# - passo 1: crie um no N associado a base de dados
# - se todos registros B pertencem a mesma classe C ENTAO transforme em no folha C
# - SENAO se CAND = {} ENTAO transforme N numa folha etiquetada com o valor C = max(count(atributo-classe(A))
# - SENAO seleciona atributo-teste A = max(Ganho(CAND))  e rotule N com o nome de atributo-teste A
#
#
# - passo 2: particao das amostras de B
# - para cada valor si do atributo-teste faca
# - crie um no-filho, ligado a N (idade; adulto) por um ramo rotulado pelo valor sj
# - SE Bi = {} ENTAO transforme o no Ni numa folha etiquetada com o valor C = max(count(atributo-Classe(A))
# - SENAO calcule Arvore(Bi, CAND –(atributo-teste))
#
# - entropia: quantidade de bits necessario para processar informacao. Entropia maxima 1. Se dado esta 100% classificado, entao entropia = 0.
#
#
# - C45
# - taxa de ganho: dados categoricos ou continuos
# - usado para dados categoricos com muitos valores
# - ganho de informacao tende a produzir overfitting
# - GINI: funciona alem de classes binarias
# - GINI = 0 quando dado esta classificado; indice de pureza

# %% [markdown]
# <h2>Árvore de decisão: overfitting</h2>
#
# - superajustamento em arvores de decisao
# - grande problema para algoritmos de aprendizagem de maquina
# - impureza causado por ruido, base nao eh classificada 100%
# - arvore nao deve crescer por causa de ruido
#
#
# - overfitting - tarefa de pos-processamento:
# - calcular taxa de erro sobre o conjunto de treinamneto
# - erro real sobre todo conjunto de dados
# - perder capacidade de generalizacao eh um problema
# - evitar overfitting:
#     - parar de crescer arvore quando nao for relevante
#     - gerar arvore completa e depois poda-la
#     - criterios de poda: analisar nos folha - se for muito pequeno, fundir no-folha
#     - depende do numero de atributos (+ registros, +regras), erro de classificacao
# - estrategias:
#     - dividir dado em treinamento e validacao
#     - criar arvore que classifica treinamento corretamente
#     - repetir are que seja prejudicial ao modelo
#     - avaliar impacto de cada no na validacao
#     - remover no que mais aumenta a acuracia

# %% [markdown]
# <h2>Árvore de decisão - atributos contínuos</h2>
#
# - criar no que testa o atributo continuo
# - tem que identificar ponto de particionamento
# - temperatura = 60 == V/F | > 65 == V/F
# - problema: espalhamento; se atributo possui muitos valores, ele sera selecionado; baixa entropia mas nao relevante
# - abordagem e usar GainRatio: taxa de ganho
# - entropia original / quantidade da informacao
# - split information

# %% [markdown]
# <h2>Classificação Bayesiana</h2>
#
# - metodo baseado em classificador estatistico
# - utiliza dados categoricos
# - probabilidade de ocorrencia de cada atributo
# - cada variavel e condicionalmente independentes, o que nem sempre e verdade
#
# - Naive Bayes: funciona bem para algoritmos multi-classe
# - pode nao ter todas combinacoes possiveis de valores
#
#
# ![Screen%20Shot%202020-09-09%20at%209.09.30%20PM.png](attachment:Screen%20Shot%202020-09-09%20at%209.09.30%20PM.png)
#
#
# - algoritmo rapido de ser treinado
# - eficiente dependendo do espaco amostral de solucoes

# %% [markdown]
# <h2>Redes Neurais Artificiais</h2>
#
# - alta acuracia e robusto a bases com erros
# - saida pode ser discreta, continua ou multivaloradas
# - supervisionado ou nao
# - problemas:
# - interpretabilidade
# - treinamento demorado e sensivel a diversos parametros (rede, neuronios)
# - epoca: quantidade vezes que precisa passar a base de dados para verificar ajustamento
# - caminhar na direcao da convergencia
#
#
# - neuronio artificial (perceptron) - neuronio base
# - entradas: multiplicadas por pesos
# - pesos simulam neuronio biologico
# - funcao de ativacao degrau que decide de dispara ou nao
# - pode ser binaria ou continua
# - 3 passos:
# - pesos aleatorios e passa exemplos da base de conhecimento com saida real
# - calcula erro
# - atualiza pesos
# - fica em loop ate que base de dados termine e decida parar
# - ou volta para o inicio (conta como nova epoca)
# - funcao do neuronio e linar
#
#
# ![Screen%20Shot%202020-09-09%20at%209.19.44%20PM.png](attachment:Screen%20Shot%202020-09-09%20at%209.19.44%20PM.png)
#
#
#
# - Redes perceptron muticamadas (MLP)
# - possui camada externa recebe as entradas com pesos
# - camada interna, camada oculta
# - camada de saida: agreacao da camada oculta nas variaveis de saida
# - se colocar um numero suficiente de neuronios escondidos, MLP aproxima qualquer camada continua
# - overfitting: rede hipertreinada, ou possui mais neuronios que precisa
# - mesmo problema que machine learning
#
#
# - redes feed-forward
# - single-layer ou multi-layer
# - implementam funcoes - nao possuem estado interno/memoria
# - nao implementam deep learning
# - bom para BI, sistemas de apoio a decisao
#
#
# - redes recorrentes
# - possuem ciclos que possuem realimentacao
# - Redes Hopfield: memoria associativa
# - maquinas Boltzmann: funcoes estocasticas de ativacao

# %% [markdown]
# <h2>Regressão Linear</h2>
#
# - previsao: modelam funcoes continuas
# - qualquer funcao pode ser modelada
# - regressoes podem ser lineares ou nao lineares (exponencial ou polinomial)
# - nao lineares: dificil de utilizar
# - intercepto (β): valor esperado de y quanto todos valores sao 0
# - ai: coeficientes angulares
# - estimacao de parametros: minimos quadrados
# - exemplo: criminalidade e analfabetismo: ha relacao
# - diagrama de dispersao
# - obter coeficiente de correlacao (0-1)
# - para minimizar erro quadratico
# - problema: correlacao nao implica em causalidade
# - fato de existir relacao entre atributos nao significa que
# - nao eh possivel identificar causa/consequencia
# - atributos correlacionados podem mascarar correlação entre atributo e a saída (exemplo: quarto/banheiro)

# %% [markdown]
# <h2>Boosting</h2>
#
# - metodo para melhorar precisao de qualquer algoritmo de aprendizagem
# - combinacao de modelos para analisar casos especificos no dataset
# - independente do modelo utilizado
# - Adaboost: Adaptive Bootsting
# - dados pre-classificados
# - particiona modelo em diversas instancias
# - primeiro constroi dominio (sub conjunto do dataset)
# - modelo aplicado em cada conjunto
# - modelos devem ser diferentes entre si (cada modelo)
# - 5 modelos, 5 hipoteses
# - seleciona modelo com menor erro
# - combinacao de arvore de decisao ate atingir objetivo
#
#
# - pode usar qualquer classificador fraco
# - rapido - apenas uma passada na base a cada iteracao
# - se base de dados for grande,
# - simples e facil de programar
# - flexbilidade - combinar algotitmos de qualquer modelo de treinamento
# - evita overfitting: modelo nao eh tao detalhado

# %% [markdown]
# <h2>K-means</h2>
#
# - analise de agrupamento
# - cada cluster e representado por um ponto central (media)
# - informa quantidade de clusters desejada
# - requer medida de distancia
# - problemas
# - pode encontrar minimos locais: solucao e o random restart
# - pode entrar em loop infinito: limitar numero de iteracoes

# %% [markdown]
# <h2>Estruturas de dados para aprendizado não supervisionado</h2>
#
# - ideia e agrupar elementos semelhantes
# - cluster: agrupamento - colecao de objetos similares mas dissimilares entre outros clusters
# - categoria homogenea mas distante de outras categorias
# - criterios de similaridade e diferenca
# - separar grupos com base em similaridade
# - descrever grupos (estatistica ou descricao manual atraves de analise exploratoria)
# - aplicacoes
#     - distribuicao e pre-processamento de dados
#     - processamento de imagens
#     - economia e marketing
#     - categorizacao de documentos
#     - identificar perfis de acesso a internet
#     - pleanejamento de cidades (agrupar casas de acordo com tipos, valores e localizacao)
#
#
# - escolha da medida e o momento mais importante
# - requisitos desejaveis
#     - escalabilidade
#     - trata diferentes tipos de atributos
#     - cluster com formas arbritarias
#     - minimo conhecimento do dominio
#     - resiliencia: valores extremos, ruidos, ordem de processamento
#
#
# - matriz de dados
# - colunas sao atributos
# - linhas sao objetos/exemplos/representacao vetorial do registro
# - matriz de distancia simetrica: matriz nxn
# - n eh o numero de registro
# - distancia entre 2 elementos
# - matriz triangular

# %% [markdown]
# <h2>Medidas de distância de variáveis qualitativas</h2>
#
# - atributos binarios ou bool so tem 2 valores
# - tratar como valores numericos pode levar a analises erroneas
# - matriz de confusao: mostra se atributo coincide ou nao
# - medida de distancia: atributos simetricos
# - distancia de jaccard: atributos assimetricos
# - casamento simples (matching): atributos simetricos
#
#
# ![Screen%20Shot%202020-09-12%20at%209.20.26%20PM.png](attachment:Screen%20Shot%202020-09-12%20at%209.20.26%20PM.png)
#
# ![Screen%20Shot%202020-09-12%20at%209.20.58%20PM.png](attachment:Screen%20Shot%202020-09-12%20at%209.20.58%20PM.png)

# %% [markdown]
# - variaveis nominais ou categoricos
# - converter formato binomial
# - medidas de distancia deve ser assimetrica
# - rank: faixa de cada variavel em intervalor 0-1
# - computa dissimilaridade continua

# %% [markdown]
# <h2>Medidas de distância de variáveis quantitativas</h2>
#
# - qualquer distancia metrica pode ser utilizada
# - Minkowski
# - distancia entre o dado e a populacao em desvio padrao
# - deve normalizar dados numericos antes de aplicar medida de distancia
# - z-score: resiliente a outliers e ruidos
# - negativo quando abaixo da media
#
#
# - min-max: normalizar por faixa de valores tradicional
#
#
# - se dados sao esparsos e ha muitos atributos
# - tratar como vetor
# - checar calculo de distancia entre eles, amplitude
# - diferenciar registros com distancias muito variaveis
# - similaridade de cosseno
#
#
# - correlacao de Pearson
# - variancia media alta entre dados

# %% [markdown]
# <h2>Métodos de agrupamento</h2>
#
# - particionamento
# - particao inicial de k partes aleatorias
# - elementos sao realocados para outras partes para melhorar o particionamento
#
#
# - densidade
# - adequados para descobrir clusters de formato arbitrario
# - definir densidade
# - x-vizinhanca de cada ponto
#
#
# - metodos hirarquivos aglometativos
# - comeca com n clusters
# - junta elementos que sao mais proximos entre si a cada iteracao
# - termina quando clusters k e atingido
# - Agnes
#
#
# - metodos hirarquivos divisorios
# - unico cluster composto por toda base
# - clusters sao subdivididos em duas partes a cada iteracao
# - termina quando k e atingido
# - DIANA

# %% [markdown]
# <h2>Algoritmos hierárquicos</h2>
#
# - Single LinkageMethod
# - cada elemento e um cluster individual
# - grupos sao funcidos com os membros mais proximos
# - cada fusao reduz numero de clusters

# %% [markdown]
# <h2>DB-outlier</h2>
#
# - analise de anomalias (valores extremos)
# - pode levar a conhecimento como:
# - fraude de telecomunicacao
# - fraude de cartoes de credito
# - segmentacao de clientes
# - performance de atletas profissionais
#
#
# - definicao: calcula distancia de um elemento comparado com toda a base de dados
# - conta elementos que estao dentro da vizinhanca
